# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
f = lambda x: x**3
d_f = lambda x: 3*x**2

x = np.linspace(-15, 15, 500)

plt.plot(x, f(x))
plt.plot(x, d_f(x))

# %% [markdown]
# ## Newton's method to find roots

# %%
x0 = -10
path = [x0]

xt = x0
for t in range(10):
    xt = xt - f(xt) / d_f(xt)
    path.append(xt)

path = np.array(path)

plt.plot(x, f(x))
plt.scatter(path, f(path))
plt.plot(path, f(path))

path, f(path)
# Out:
# (array([-10.        ,  -6.66666667,  -4.44444444,  -2.96296296,
#          -1.97530864,  -1.31687243,  -0.87791495,  -0.58527663,
#          -0.39018442,  -0.26012295,  -0.1734153 ]),
#  array([-1.00000000e+03, -2.96296296e+02, -8.77914952e+01, -2.60122949e+01,
#         -7.70734663e+00, -2.28365826e+00, -6.76639485e-01, -2.00485773e-01,
#         -5.94031921e-02, -1.76009458e-02, -5.21509505e-03]))

# %% [markdown]
# ## Newton's method to find optima

# %%
d2_f = lambda x: 6*x

# %%
x0 = -10
path = [x0]

xt = x0
for t in range(10):
    xt = xt - d_f(xt) / d2_f(xt)
    path.append(xt)

path = np.array(path)

plt.plot(x, f(x))
plt.scatter(path, f(path))
plt.plot(path, f(path))

path, f(path)
# Out:
# (array([-1.000000e+01, -5.000000e+00, -2.500000e+00, -1.250000e+00,
#         -6.250000e-01, -3.125000e-01, -1.562500e-01, -7.812500e-02,
#         -3.906250e-02, -1.953125e-02, -9.765625e-03]),
#  array([-1.00000000e+03, -1.25000000e+02, -1.56250000e+01, -1.95312500e+00,
#         -2.44140625e-01, -3.05175781e-02, -3.81469727e-03, -4.76837158e-04,
#         -5.96046448e-05, -7.45058060e-06, -9.31322575e-07]))

# %% [markdown]
# ## General gradient ascent/descent

# %%
x0 = -10
path = [x0]

xt = x0
for t in range(10):
    xt = xt - 0.002 * d_f(xt)
    path.append(xt)

path = np.array(path)

plt.plot(x, f(x))
plt.scatter(path, f(path))
plt.plot(path, f(path))

path, f(path)
# Out:
# (array([-10.        , -10.6       , -11.27416   , -12.0368001 ,
#         -12.90610744, -13.9055131 , -15.06569287, -16.42754347,
#         -18.04672858, -20.00083506, -22.40103548]),
#  array([ -1000.        ,  -1191.016     ,  -1433.02108917,  -1743.94644691,
#          -2149.73946226,  -2688.8158248 ,  -3419.53716758,  -4433.20562492,
#          -5877.53819626,  -8001.00211072, -11240.98275241]))
